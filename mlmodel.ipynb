# %%
import pandas as pd

# %%
df = pd.read_excel(r"c:\Users\gunda\Downloads\Crop_recommendation (4).xlsx",na_values=[' ?','?','? '])

# %%
df
# Out:
#           N     P     K  temperature   humidity        ph    rainfall   label
# 0      90.0  42.0  43.0    20.879744  82.002744  6.502985  202.935536    rice
# 1      85.0  58.0  41.0    21.770462  80.319644  7.038096  226.655537    rice
# 2      60.0  55.0   0.0    23.004459  82.320763  7.840207  263.964248    rice
# 3      74.0  35.0  40.0    26.491096  80.158363  6.980401    0.000000    rice
# 4      78.0  42.0  42.0    20.130175  81.604873  7.628473  262.717340    rice
# ...     ...   ...   ...          ...        ...       ...         ...     ...
# 2195  107.0  34.0  32.0    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99.0  15.0  27.0    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118.0  33.0  30.0    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117.0  32.0  34.0    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104.0   NaN  30.0    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# N               39
# P               96
# K              141
# temperature      1
# humidity         1
# ph              15
# rainfall         0
# label            0
# dtype: int64

# %%
df['N'].fillna(df.N.median(),inplace=True)

# %%
df['P'].fillna(df.N.median(),inplace=True)

# %%
df['K'].fillna(df.N.median(),inplace=True)

# %%
df['temperature'].fillna(df.N.median(),inplace=True)

# %%
df['humidity'].fillna(df.humidity.median(),inplace=True)

# %%
df['ph'].fillna(df.ph.median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
pip install scikit-learn
# Out:
# ...
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/fe/6b/db949ed5ac367987b1f250f070f340b7715d22f0c9c965bdf07de6ca75a3/scikit_learn-1.3.2-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for scipy>=1.5.0 from https://files.pythonhosted.org/packages/c6/a1/357e4cd43af2748e1e0407ae0e9a5ea8aaaa6b702833c81be11670dcbad8/scipy-1.11.4-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 60.4/60.4 kB 1.1 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for joblib>=1.1.1 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['Crop_encode']=lb.fit_transform(df['label'])

# %%
X = df.drop(['label','Crop_encode'],axis=1)

# %%
Y = df['Crop_encode']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test =train_test_split(X,Y,test_size=0.2,random_state=500)

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(X_train,Y_train)
# Out:
# c:\Users\gunda\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
import pickle

# %%
with open('model.pkl','rb') as model_file:
    mlmodel = pickle.load(model_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 with open('model.pkl','rb') as model_file:
#       2     mlmodel = pickle.load(model_file)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model.pkl'
